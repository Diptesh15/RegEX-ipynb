# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib notebook

# %%
data = np.arange(10)
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.scatter(data, data)

# %% [markdown]
# Figure = Container act as canvas. We have to create another figure to create new plot individually, else they will be in single figure or we need to close figure for that particular plot.

# %%
fig = plt.figure(figsize = (8, 8))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
p1 = fig.add_subplot(2, 2, 1) # (along row, along column, index subplot)
p2 = fig.add_subplot(2, 2, 2)
p3 = fig.add_subplot(2, 2, 3)
p4 = fig.add_subplot(2, 2, 4)

# %%
p1.plot(np.arange(10), 'k-')  #plot() can work even if we specify only 1 axis it will by default take same values for another axis

# %%
p2.scatter(np.arange(30), np.arange(30) + np.random.randn(30))

# %%
p3.plot(np.arange(10), 'm--')

# %%
p4.plot(np.arange(10), 'co-')

# %%
fig, axes = plt.subplots(2, 1)  # initialize fig, objs, plots
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes[0].plot(np.arange(30), np.arange(30) + np.random.randn(30))

# %%
axes[1].scatter(np.arange(30), np.arange(30) + np.random.randn(30))

# %% [markdown]
# # Types of Plots

# %% [markdown]
# ## Line Plot

# %%
# Line plot
plt.figure()
x = np.arange(10)
y = np.arange(10) * 2
plt.plot(x, y, 'r-*')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(figsize = (8, 8))
plt.plot(np.random.randn(30), 'mo-', label = 'FirstPlot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple line plot')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure()
x = np.arange(10)
y = x ** 2
z = x ** 3
plt.plot(x, y, 'mo-', label = "Squares")
plt.plot(x, z, 'b*-', label = 'Cubes')
plt.title("Squares and Cubes")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Scatter Plot

# %%
# Scatter plot

plt.figure()
x = np.arange(10)
y = x ** 2
plt.scatter(x, y, s = 200, c = 'm')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xticks(np.arange(10))
# Out:
# ([<matplotlib.axis.XTick at 0x2a8a22a0490>,
# ...
#  [Text(-2.0, 0, '−2'),
#   Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.yticks(np.arange(0, 100, 5))
# Out:
# ([<matplotlib.axis.YTick at 0x2a8a2772850>,
# ...
#  [Text(0, -10.0, '−10'),
#   Text(0, 0.0, '0'),
#   Text(0, 10.0, '10'),
#   Text(0, 20.0, '20'),
#   Text(0, 30.0, '30'),
#   Text(0, 40.0, '40'),
#   Text(0, 50.0, '50'),
#   Text(0, 60.0, '60'),
#   Text(0, 70.0, '70'),
#   Text(0, 80.0, '80'),
#   Text(0, 90.0, '90'),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## Bar Plots

# %%
# Bar plots

plt.figure()
x = np.arange(10)
y = x * 2
plt.bar(x, y, width = 0.8)
plt.xticks(x)
plt.yticks(y)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.YTick at 0x2a8a6e42be0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure()
x = np.arange(10)
y = x * 2
z = x * 4
plt.bar(x,y, width = 0.4, color = 'm')
plt.bar(x,z, width = 0.4, color = 'c', bottom = x)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 10 artists>

# %%
plt.figure()
x = np.arange(10)
y = x * 2
z = x * 4
plt.bar(x - 0.3, y, width = 0.4, color = 'm')
plt.bar(x + 0.2, z, width = 0.4, color = 'c')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Histogram

# %%
plt.figure()
plt.hist([1,2,3,4,5,4,2,5,6,7,8,9,5,6,7,0,4,3,5,6,7], width = 0.8)
plt.xticks(range(10))
plt.yticks(range(5))
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.YTick at 0x2a8a63443a0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure()
x = np.random.normal(100, 10, 500)
plt.hist(x)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  3.,  11.,  32.,  66.,  91., 112.,  94.,  65.,  17.,   9.]),
#  array([ 70.60661427,  76.11474676,  81.62287924,  87.13101173,
#          92.63914422,  98.14727671, 103.6554092 , 109.16354169,
#         114.67167418, 120.17980666, 125.68793915]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Pie Chart

# %%
plt.figure()
x = np.array([10, 20, 30, 80])
plt.pie(x)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x2a8a7a51850>,
# ...
#  [Text(1.0724207009445805, 0.24477303810986792, ''),
#   Text(0.6858387475358717, 0.8600146582346299, ''),
#   Text(-0.4772721793080792, 0.9910657227744873, ''),
#   Text(-0.2447728623971385, -1.072420741049851, '')])

# %%
plt.figure()
x = [30, 20, 40, 30, 10]
food = ['Bananas', 'Apples', 'Grapes', 'Chickoo', 'Mango']
plt.pie(x, labels = food)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x2a8a2568640>,
# ...
#  [Text(0.8233618203614949, 0.7294349270298247, 'Bananas'),
#   Text(-0.3900654016728485, 1.0285178571214986, 'Apples'),
#   Text(-1.0680359783135132, -0.2632473153289448, 'Grapes'),
#   Text(0.3900654979696379, -1.0285178206009358, 'Chickoo'),
#   Text(1.0680360337692223, -0.2632470903362633, 'Mango')])
